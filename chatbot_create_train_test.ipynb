# %%
import sqlite3
import pandas as pd

timeframes = ['2015-01']

# %%
for timeframe in timeframes:
    connection = sqlite3.connect('{}.db'.format(timeframe))
    c = connection.cursor()
    limit = 5000
    last_unix = 0
    cur_length = limit
    counter = 0
    test_done = False

    while cur_length == limit:

        df = pd.read_sql("SELECT * FROM parent_reply WHERE unix > {} and parent NOT NULL and score > 0 ORDER BY unix ASC LIMIT {}".format(last_unix,limit),connection)
        last_unix = df.tail(1)['unix'].values[0]
        cur_length = len(df)

        if not test_done:
            with open('test.from','a', encoding='utf8') as f:
                for content in df['parent'].values:
                    f.write(content+'\n')

            with open('test.to','a', encoding='utf8') as f:
                for content in df['comment'].values:
                    f.write(str(content)+'\n')

            test_done = True

        else:
            with open('train.from','a', encoding='utf8') as f:
                for content in df['parent'].values:
                    f.write(content+'\n')

            with open('train.to','a', encoding='utf8') as f:
                for content in df['comment'].values:
                    f.write(str(content)+'\n')

        counter += 1
        if counter % 1 == 0:
            print(counter*limit,'rows completed so far')
# Out:
# 5000 rows completed so far
# 10000 rows completed so far
# 15000 rows completed so far
# 20000 rows completed so far
# 25000 rows completed so far
# 30000 rows completed so far
# 35000 rows completed so far
# 40000 rows completed so far
# 45000 rows completed so far
# 50000 rows completed so far
# 55000 rows completed so far
# 60000 rows completed so far
# 65000 rows completed so far
# 70000 rows completed so far
# 75000 rows completed so far
# 80000 rows completed so far
# 85000 rows completed so far
# 90000 rows completed so far
# 95000 rows completed so far
# 100000 rows completed so far
# 105000 rows completed so far
# 110000 rows completed so far
# 115000 rows completed so far
# 120000 rows completed so far
# 125000 rows completed so far
# 130000 rows completed so far
# 135000 rows completed so far
# 140000 rows completed so far
# 145000 rows completed so far
# 150000 rows completed so far
# 155000 rows completed so far
# 160000 rows completed so far
# 165000 rows completed so far
# 170000 rows completed so far
# 175000 rows completed so far
# 180000 rows completed so far
# 185000 rows completed so far
# 190000 rows completed so far
# 195000 rows completed so far
# 200000 rows completed so far
# 205000 rows completed so far
# 210000 rows completed so far
# 215000 rows completed so far
# 220000 rows completed so far
# 225000 rows completed so far
# 230000 rows completed so far
# 235000 rows completed so far
# 240000 rows completed so far
# 245000 rows completed so far
# 250000 rows completed so far
# 255000 rows completed so far
# 260000 rows completed so far
# 265000 rows completed so far
# 270000 rows completed so far
# 275000 rows completed so far
# 280000 rows completed so far
# 285000 rows completed so far
# 290000 rows completed so far
# 295000 rows completed so far
# 300000 rows completed so far
# 305000 rows completed so far
# 310000 rows completed so far
# 315000 rows completed so far
# 320000 rows completed so far
# 325000 rows completed so far
# 330000 rows completed so far
# 335000 rows completed so far
# 340000 rows completed so far
# 345000 rows completed so far
# 350000 rows completed so far
# 355000 rows completed so far
# 360000 rows completed so far
# 365000 rows completed so far
# 370000 rows completed so far
# 375000 rows completed so far
# 380000 rows completed so far
# 385000 rows completed so far
# 390000 rows completed so far
# 395000 rows completed so far
# 400000 rows completed so far
# 405000 rows completed so far
# 410000 rows completed so far
# 415000 rows completed so far
# 420000 rows completed so far
# 425000 rows completed so far
# 430000 rows completed so far
# 435000 rows completed so far
# 440000 rows completed so far
# 445000 rows completed so far
# 450000 rows completed so far
# 455000 rows completed so far
# 460000 rows completed so far
# 465000 rows completed so far
# 470000 rows completed so far
# 475000 rows completed so far
# 480000 rows completed so far
# 485000 rows completed so far
# 490000 rows completed so far
# 495000 rows completed so far
# 500000 rows completed so far
# 505000 rows completed so far
# 510000 rows completed so far
# 515000 rows completed so far
# 520000 rows completed so far
# 525000 rows completed so far
# 530000 rows completed so far
# 535000 rows completed so far
# 540000 rows completed so far
# 545000 rows completed so far
# 550000 rows completed so far
# 555000 rows completed so far
# 560000 rows completed so far
# 565000 rows completed so far
# 570000 rows completed so far
# 575000 rows completed so far
# 580000 rows completed so far
# 585000 rows completed so far
# 590000 rows completed so far
# 595000 rows completed so far
# 600000 rows completed so far
# 605000 rows completed so far
# 610000 rows completed so far
# 615000 rows completed so far
# 620000 rows completed so far
# 625000 rows completed so far
# 630000 rows completed so far
# 635000 rows completed so far
# 640000 rows completed so far
# 645000 rows completed so far
# 650000 rows completed so far
# 655000 rows completed so far
# 660000 rows completed so far
# 665000 rows completed so far
# 670000 rows completed so far
# 675000 rows completed so far
# 680000 rows completed so far
# 685000 rows completed so far
# 690000 rows completed so far
# 695000 rows completed so far
# 700000 rows completed so far
# 705000 rows completed so far
# 710000 rows completed so far
# 715000 rows completed so far
# 720000 rows completed so far
# 725000 rows completed so far
# 730000 rows completed so far
# 735000 rows completed so far
# 740000 rows completed so far
# 745000 rows completed so far
# 750000 rows completed so far
# 755000 rows completed so far
# 760000 rows completed so far
# 765000 rows completed so far
# 770000 rows completed so far
# 775000 rows completed so far
# 780000 rows completed so far
# 785000 rows completed so far
# 790000 rows completed so far
# 795000 rows completed so far
# 800000 rows completed so far
# 805000 rows completed so far
# 810000 rows completed so far
# 815000 rows completed so far
# 820000 rows completed so far
# 825000 rows completed so far
# 830000 rows completed so far
# 835000 rows completed so far
# 840000 rows completed so far
# 845000 rows completed so far
# 850000 rows completed so far
# 855000 rows completed so far
# 860000 rows completed so far
# 865000 rows completed so far
# 870000 rows completed so far
# 875000 rows completed so far
# 880000 rows completed so far
# 885000 rows completed so far
# 890000 rows completed so far
# 895000 rows completed so far
# 900000 rows completed so far
# 905000 rows completed so far
# 910000 rows completed so far
# 915000 rows completed so far
# 920000 rows completed so far
# 925000 rows completed so far
# 930000 rows completed so far
# 935000 rows completed so far
# 940000 rows completed so far
# 945000 rows completed so far
# 950000 rows completed so far
# 955000 rows completed so far
# 960000 rows completed so far
# 965000 rows completed so far
# 970000 rows completed so far
# 975000 rows completed so far
# 980000 rows completed so far
# 985000 rows completed so far
# 990000 rows completed so far
# 995000 rows completed so far
# 1000000 rows completed so far
# 1005000 rows completed so far
# 1010000 rows completed so far
# 1015000 rows completed so far
# 1020000 rows completed so far
# 1025000 rows completed so far
# 1030000 rows completed so far
# 1035000 rows completed so far
# 1040000 rows completed so far
# 1045000 rows completed so far
# 1050000 rows completed so far
# 1055000 rows completed so far
# 1060000 rows completed so far
# 1065000 rows completed so far
# 1070000 rows completed so far
# 1075000 rows completed so far
# 1080000 rows completed so far
# 1085000 rows completed so far
# 1090000 rows completed so far
# 1095000 rows completed so far
# 1100000 rows completed so far
# 1105000 rows completed so far
# 1110000 rows completed so far
# 1115000 rows completed so far
# 1120000 rows completed so far
# 1125000 rows completed so far
# 1130000 rows completed so far
# 1135000 rows completed so far
# 1140000 rows completed so far
# 1145000 rows completed so far
# 1150000 rows completed so far
# 1155000 rows completed so far
# 1160000 rows completed so far
# 1165000 rows completed so far
# 1170000 rows completed so far
# 1175000 rows completed so far
# 1180000 rows completed so far
# 1185000 rows completed so far
# 1190000 rows completed so far
# 1195000 rows completed so far
# 1200000 rows completed so far
# 1205000 rows completed so far
# 1210000 rows completed so far
# 1215000 rows completed so far
# 1220000 rows completed so far
# 1225000 rows completed so far
# 1230000 rows completed so far
# 1235000 rows completed so far
# 1240000 rows completed so far
# 1245000 rows completed so far
# 1250000 rows completed so far
# 1255000 rows completed so far
# 1260000 rows completed so far
# 1265000 rows completed so far
# 1270000 rows completed so far
# 1275000 rows completed so far
# 1280000 rows completed so far
# 1285000 rows completed so far
# 1290000 rows completed so far
# 1295000 rows completed so far
# 1300000 rows completed so far
# 1305000 rows completed so far
# 1310000 rows completed so far
# 1315000 rows completed so far
# 1320000 rows completed so far
# 1325000 rows completed so far
# 1330000 rows completed so far
# 1335000 rows completed so far
# 1340000 rows completed so far
# 1345000 rows completed so far
# 1350000 rows completed so far
# 1355000 rows completed so far
# 1360000 rows completed so far
# 1365000 rows completed so far
# 1370000 rows completed so far
# 1375000 rows completed so far
# 1380000 rows completed so far
# 1385000 rows completed so far
# 1390000 rows completed so far
# 1395000 rows completed so far
# 1400000 rows completed so far
# 1405000 rows completed so far
# 1410000 rows completed so far
# 1415000 rows completed so far
# 1420000 rows completed so far
# 1425000 rows completed so far
# 1430000 rows completed so far
# 1435000 rows completed so far
# 1440000 rows completed so far
# 1445000 rows completed so far
# 1450000 rows completed so far
# 1455000 rows completed so far
# 1460000 rows completed so far
# 1465000 rows completed so far
# 1470000 rows completed so far
# 1475000 rows completed so far
# 1480000 rows completed so far
# 1485000 rows completed so far
# 1490000 rows completed so far
# 1495000 rows completed so far
# 1500000 rows completed so far
# 1505000 rows completed so far
# 1510000 rows completed so far
# 1515000 rows completed so far
# 1520000 rows completed so far
# 1525000 rows completed so far
# 1530000 rows completed so far
# 1535000 rows completed so far
# 1540000 rows completed so far
# 1545000 rows completed so far
# 1550000 rows completed so far
# 1555000 rows completed so far
# 1560000 rows completed so far
# 1565000 rows completed so far
# 1570000 rows completed so far
# 1575000 rows completed so far
# 1580000 rows completed so far
# 1585000 rows completed so far
# 1590000 rows completed so far
# 1595000 rows completed so far
# 1600000 rows completed so far
# 1605000 rows completed so far
# 1610000 rows completed so far
# 1615000 rows completed so far
# 1620000 rows completed so far
# 1625000 rows completed so far
# 1630000 rows completed so far
# 1635000 rows completed so far
# 1640000 rows completed so far
# 1645000 rows completed so far
# 1650000 rows completed so far
# 1655000 rows completed so far
# 1660000 rows completed so far
# 1665000 rows completed so far
# 1670000 rows completed so far
# 1675000 rows completed so far
# 1680000 rows completed so far
# 1685000 rows completed so far
# 1690000 rows completed so far
# 1695000 rows completed so far
# 1700000 rows completed so far
# 1705000 rows completed so far
# 1710000 rows completed so far
# 1715000 rows completed so far
# 1720000 rows completed so far
# 1725000 rows completed so far
# 1730000 rows completed so far
# 1735000 rows completed so far
# 1740000 rows completed so far
# 1745000 rows completed so far
# 1750000 rows completed so far
# 1755000 rows completed so far
# 1760000 rows completed so far
# 1765000 rows completed so far
# 1770000 rows completed so far
# 1775000 rows completed so far
# 1780000 rows completed so far
# 1785000 rows completed so far
# 1790000 rows completed so far
# 1795000 rows completed so far
# 1800000 rows completed so far
# 1805000 rows completed so far
# 1810000 rows completed so far
# 1815000 rows completed so far
# 1820000 rows completed so far
# 1825000 rows completed so far
# 1830000 rows completed so far
# 1835000 rows completed so far
# 1840000 rows completed so far
# 1845000 rows completed so far
# 1850000 rows completed so far
# 1855000 rows completed so far
# 1860000 rows completed so far
# 1865000 rows completed so far
# 1870000 rows completed so far
# 1875000 rows completed so far
# 1880000 rows completed so far
# 1885000 rows completed so far
# 1890000 rows completed so far
# 1895000 rows completed so far
# 1900000 rows completed so far
# 1905000 rows completed so far
# 1910000 rows completed so far
# 1915000 rows completed so far
# 1920000 rows completed so far
# 1925000 rows completed so far
# 1930000 rows completed so far
# 1935000 rows completed so far
# 1940000 rows completed so far
# 1945000 rows completed so far
# 1950000 rows completed so far
# 1955000 rows completed so far
# 1960000 rows completed so far
# 1965000 rows completed so far
# 1970000 rows completed so far
# 1975000 rows completed so far
# 1980000 rows completed so far
# 1985000 rows completed so far
# 1990000 rows completed so far
# 1995000 rows completed so far
# 2000000 rows completed so far
# 2005000 rows completed so far
# 2010000 rows completed so far
# 2015000 rows completed so far
# 2020000 rows completed so far
# 2025000 rows completed so far
# 2030000 rows completed so far
# 2035000 rows completed so far
# 2040000 rows completed so far
# 2045000 rows completed so far
# 2050000 rows completed so far
# 2055000 rows completed so far
# 2060000 rows completed so far
# 2065000 rows completed so far
# 2070000 rows completed so far
# 2075000 rows completed so far
# 2080000 rows completed so far
# 2085000 rows completed so far
# 2090000 rows completed so far
# 2095000 rows completed so far
# 2100000 rows completed so far
# 2105000 rows completed so far
# 2110000 rows completed so far
# 2115000 rows completed so far
# 2120000 rows completed so far
# 2125000 rows completed so far
# 2130000 rows completed so far
# 2135000 rows completed so far
# 2140000 rows completed so far
# 2145000 rows completed so far
# 2150000 rows completed so far
# 2155000 rows completed so far
# 2160000 rows completed so far
# 2165000 rows completed so far
# 2170000 rows completed so far
# 2175000 rows completed so far
# 2180000 rows completed so far
# 2185000 rows completed so far
# 2190000 rows completed so far
# 2195000 rows completed so far
# 2200000 rows completed so far
# 2205000 rows completed so far
# 2210000 rows completed so far
# 2215000 rows completed so far
# 2220000 rows completed so far
# 2225000 rows completed so far
# 2230000 rows completed so far
# 2235000 rows completed so far
# 2240000 rows completed so far
# 2245000 rows completed so far
# 2250000 rows completed so far
# 2255000 rows completed so far
# 2260000 rows completed so far
# 2265000 rows completed so far
# 2270000 rows completed so far
# 2275000 rows completed so far
# 2280000 rows completed so far
# 2285000 rows completed so far
# 2290000 rows completed so far
# 2295000 rows completed so far
# 2300000 rows completed so far
# 2305000 rows completed so far
# 2310000 rows completed so far
# 2315000 rows completed so far
# 2320000 rows completed so far
# 2325000 rows completed so far
# 2330000 rows completed so far
# 2335000 rows completed so far
# 2340000 rows completed so far
# 2345000 rows completed so far
# 2350000 rows completed so far
# 2355000 rows completed so far
# 2360000 rows completed so far
# 2365000 rows completed so far
# 2370000 rows completed so far
# 2375000 rows completed so far
# 2380000 rows completed so far
# 2385000 rows completed so far
# 2390000 rows completed so far
# 2395000 rows completed so far
# 2400000 rows completed so far
# 2405000 rows completed so far
# 2410000 rows completed so far
# 2415000 rows completed so far
# 2420000 rows completed so far
# 2425000 rows completed so far
# 2430000 rows completed so far
# 2435000 rows completed so far
# 2440000 rows completed so far
# 2445000 rows completed so far
# 2450000 rows completed so far
# 2455000 rows completed so far
# 2460000 rows completed so far
# 2465000 rows completed so far
# 2470000 rows completed so far
# 2475000 rows completed so far
# 2480000 rows completed so far
# 2485000 rows completed so far
# 2490000 rows completed so far
# 2495000 rows completed so far
# 2500000 rows completed so far
# 2505000 rows completed so far
# 2510000 rows completed so far
# 2515000 rows completed so far
# 2520000 rows completed so far
# 2525000 rows completed so far
# 2530000 rows completed so far
# 2535000 rows completed so far
# 2540000 rows completed so far
# 2545000 rows completed so far
# 2550000 rows completed so far
# 2555000 rows completed so far
# 2560000 rows completed so far
# 2565000 rows completed so far
# 2570000 rows completed so far
# 2575000 rows completed so far
# 2580000 rows completed so far
# 2585000 rows completed so far
# 2590000 rows completed so far
# 2595000 rows completed so far
# 2600000 rows completed so far
# 2605000 rows completed so far
# 2610000 rows completed so far
# 2615000 rows completed so far
# 2620000 rows completed so far
# 2625000 rows completed so far
# 2630000 rows completed so far
# 2635000 rows completed so far
# 2640000 rows completed so far
# 2645000 rows completed so far
# 2650000 rows completed so far
# 2655000 rows completed so far
# 2660000 rows completed so far
# 2665000 rows completed so far
# 2670000 rows completed so far
# 2675000 rows completed so far
# 2680000 rows completed so far
# 2685000 rows completed so far
# 2690000 rows completed so far
# 2695000 rows completed so far
# 2700000 rows completed so far
# 2705000 rows completed so far
# 2710000 rows completed so far
# 2715000 rows completed so far
# 2720000 rows completed so far
# 2725000 rows completed so far
# 2730000 rows completed so far
# 2735000 rows completed so far
# 2740000 rows completed so far
# 2745000 rows completed so far
# 2750000 rows completed so far
# 2755000 rows completed so far
# 2760000 rows completed so far
# 2765000 rows completed so far
# 2770000 rows completed so far
# 2775000 rows completed so far
# 2780000 rows completed so far
# 2785000 rows completed so far
# 2790000 rows completed so far
# 2795000 rows completed so far
# 2800000 rows completed so far
# 2805000 rows completed so far
# 2810000 rows completed so far
# 2815000 rows completed so far
# 2820000 rows completed so far
# 2825000 rows completed so far
# 2830000 rows completed so far
# 2835000 rows completed so far
# 2840000 rows completed so far
# 2845000 rows completed so far
# 2850000 rows completed so far
# 2855000 rows completed so far
# 2860000 rows completed so far
# 2865000 rows completed so far
# 2870000 rows completed so far
# 2875000 rows completed so far
# 2880000 rows completed so far
# 2885000 rows completed so far
# 2890000 rows completed so far
# 2895000 rows completed so far
# 2900000 rows completed so far
# 2905000 rows completed so far
# 2910000 rows completed so far
# 2915000 rows completed so far
# 2920000 rows completed so far
# 2925000 rows completed so far
# 2930000 rows completed so far
# 2935000 rows completed so far
# 2940000 rows completed so far
# 2945000 rows completed so far
# 2950000 rows completed so far
# 2955000 rows completed so far
# 2960000 rows completed so far
# 2965000 rows completed so far
# 2970000 rows completed so far
# 2975000 rows completed so far
# 2980000 rows completed so far
# 2985000 rows completed so far
# 2990000 rows completed so far
# 2995000 rows completed so far
# 3000000 rows completed so far
# 3005000 rows completed so far
# 3010000 rows completed so far
# 3015000 rows completed so far
# 3020000 rows completed so far
# 3025000 rows completed so far
# 3030000 rows completed so far
# 3035000 rows completed so far
# 3040000 rows completed so far
# 3045000 rows completed so far
# 3050000 rows completed so far
# 3055000 rows completed so far
# 3060000 rows completed so far
# 3065000 rows completed so far
# 3070000 rows completed so far
# 3075000 rows completed so far
# 3080000 rows completed so far
# 3085000 rows completed so far
# 3090000 rows completed so far
# 3095000 rows completed so far
# 3100000 rows completed so far
# 3105000 rows completed so far
# 3110000 rows completed so far
# 3115000 rows completed so far
# 3120000 rows completed so far
# 3125000 rows completed so far
# 3130000 rows completed so far
# 3135000 rows completed so far
# 3140000 rows completed so far
# 3145000 rows completed so far
# 3150000 rows completed so far
# 3155000 rows completed so far
# 3160000 rows completed so far
# 3165000 rows completed so far
# 3170000 rows completed so far
# 3175000 rows completed so far
# 3180000 rows completed so far
# 3185000 rows completed so far
# 3190000 rows completed so far
# 3195000 rows completed so far
# 3200000 rows completed so far
# 3205000 rows completed so far
# 3210000 rows completed so far
# 3215000 rows completed so far
# 3220000 rows completed so far
# 3225000 rows completed so far
# 3230000 rows completed so far
# 3235000 rows completed so far
# 3240000 rows completed so far
# 3245000 rows completed so far
# 3250000 rows completed so far
# 3255000 rows completed so far
# 3260000 rows completed so far
# 3265000 rows completed so far
# 3270000 rows completed so far
# 3275000 rows completed so far
# 3280000 rows completed so far
# 3285000 rows completed so far
# 3290000 rows completed so far
# 3295000 rows completed so far
# 3300000 rows completed so far
# 3305000 rows completed so far
# 3310000 rows completed so far
# 3315000 rows completed so far
# 3320000 rows completed so far
# 3325000 rows completed so far
# 3330000 rows completed so far
# 3335000 rows completed so far
# 3340000 rows completed so far
# 3345000 rows completed so far
# 3350000 rows completed so far
# 3355000 rows completed so far
# 3360000 rows completed so far
# 3365000 rows completed so far
# 3370000 rows completed so far
# 3375000 rows completed so far
# 3380000 rows completed so far
# 3385000 rows completed so far
# 3390000 rows completed so far
# 3395000 rows completed so far
# 3400000 rows completed so far
# 3405000 rows completed so far
# 3410000 rows completed so far
# 3415000 rows completed so far
# 3420000 rows completed so far
# 3425000 rows completed so far
# 3430000 rows completed so far
# 3435000 rows completed so far
# 3440000 rows completed so far
# 3445000 rows completed so far
# 3450000 rows completed so far
# 3455000 rows completed so far
# 3460000 rows completed so far
# 3465000 rows completed so far
# 3470000 rows completed so far
# 3475000 rows completed so far
# 3480000 rows completed so far
# 3485000 rows completed so far
# 3490000 rows completed so far
# 3495000 rows completed so far
# 3500000 rows completed so far
# 3505000 rows completed so far
# 3510000 rows completed so far
# 3515000 rows completed so far
# 3520000 rows completed so far
# 3525000 rows completed so far
# 3530000 rows completed so far
# 3535000 rows completed so far
# 3540000 rows completed so far
# 3545000 rows completed so far
# 3550000 rows completed so far
# 3555000 rows completed so far
# 3560000 rows completed so far
# 3565000 rows completed so far
# 3570000 rows completed so far
# 3575000 rows completed so far
# 3580000 rows completed so far
# 3585000 rows completed so far
# 3590000 rows completed so far
# 3595000 rows completed so far
# 3600000 rows completed so far
# 3605000 rows completed so far
# 3610000 rows completed so far
# 3615000 rows completed so far
# 3620000 rows completed so far
# 3625000 rows completed so far
# 3630000 rows completed so far
# 3635000 rows completed so far
# 3640000 rows completed so far
# 3645000 rows completed so far
# 3650000 rows completed so far
# 3655000 rows completed so far
# 3660000 rows completed so far
# 3665000 rows completed so far
# 3670000 rows completed so far
# 3675000 rows completed so far
# 3680000 rows completed so far
# 3685000 rows completed so far
# 3690000 rows completed so far
# 3695000 rows completed so far
# 3700000 rows completed so far
# 3705000 rows completed so far
# 3710000 rows completed so far
# 3715000 rows completed so far
# 3720000 rows completed so far
# 3725000 rows completed so far
# 3730000 rows completed so far
# 3735000 rows completed so far
# 3740000 rows completed so far
# 3745000 rows completed so far
# 3750000 rows completed so far
# 3755000 rows completed so far
# 3760000 rows completed so far
# 3765000 rows completed so far
# 3770000 rows completed so far
# 3775000 rows completed so far
# 3780000 rows completed so far
# 3785000 rows completed so far
# 3790000 rows completed so far
# 3795000 rows completed so far
# 3800000 rows completed so far
# 3805000 rows completed so far
# 3810000 rows completed so far
# 3815000 rows completed so far
# 3820000 rows completed so far
# 3825000 rows completed so far
# 3830000 rows completed so far
# 3835000 rows completed so far
# 3840000 rows completed so far
# 3845000 rows completed so far
# 3850000 rows completed so far
# 3855000 rows completed so far
# 3860000 rows completed so far
# 3865000 rows completed so far
# 3870000 rows completed so far
# 3875000 rows completed so far
# 3880000 rows completed so far
# 3885000 rows completed so far
# 3890000 rows completed so far
# 3895000 rows completed so far
# 3900000 rows completed so far
# 3905000 rows completed so far
# 3910000 rows completed so far
# 3915000 rows completed so far
# 3920000 rows completed so far
# 3925000 rows completed so far
# 3930000 rows completed so far
# 3935000 rows completed so far
# 3940000 rows completed so far
# 3945000 rows completed so far
# 3950000 rows completed so far
# 3955000 rows completed so far
# 3960000 rows completed so far
# 3965000 rows completed so far
# 3970000 rows completed so far
# 3975000 rows completed so far
# 3980000 rows completed so far
# 3985000 rows completed so far
# 3990000 rows completed so far
# 3995000 rows completed so far
# 4000000 rows completed so far
# 4005000 rows completed so far
# 4010000 rows completed so far
# 4015000 rows completed so far
# 4020000 rows completed so far
# 4025000 rows completed so far
# 4030000 rows completed so far
# 4035000 rows completed so far
# 4040000 rows completed so far
# 4045000 rows completed so far
# 4050000 rows completed so far
# 4055000 rows completed so far
# 4060000 rows completed so far
# 4065000 rows completed so far
# 4070000 rows completed so far
# 4075000 rows completed so far
# 4080000 rows completed so far
# 4085000 rows completed so far
# 4090000 rows completed so far
# 4095000 rows completed so far
# 4100000 rows completed so far
# 4105000 rows completed so far
# 4110000 rows completed so far
# 4115000 rows completed so far
# 4120000 rows completed so far
# 4125000 rows completed so far
# 4130000 rows completed so far
# 4135000 rows completed so far
# 4140000 rows completed so far
# 4145000 rows completed so far
# 4150000 rows completed so far
# 4155000 rows completed so far
# 4160000 rows completed so far
# 4165000 rows completed so far
# 4170000 rows completed so far
# 4175000 rows completed so far
# 4180000 rows completed so far
# 4185000 rows completed so far
# 4190000 rows completed so far
# 4195000 rows completed so far
# 4200000 rows completed so far
# 4205000 rows completed so far
# 4210000 rows completed so far
# 4215000 rows completed so far
# 4220000 rows completed so far
# 4225000 rows completed so far
# 4230000 rows completed so far
# 4235000 rows completed so far
# 4240000 rows completed so far
# 4245000 rows completed so far
# 4250000 rows completed so far
# 4255000 rows completed so far
# 4260000 rows completed so far
# 4265000 rows completed so far
# 4270000 rows completed so far
# 4275000 rows completed so far
# 4280000 rows completed so far
# 4285000 rows completed so far
# 4290000 rows completed so far
# 4295000 rows completed so far
# 4300000 rows completed so far
# 4305000 rows completed so far
# 4310000 rows completed so far
# 4315000 rows completed so far
# 4320000 rows completed so far
# 4325000 rows completed so far
# 4330000 rows completed so far
# 4335000 rows completed so far
# 4340000 rows completed so far
# 4345000 rows completed so far
# 4350000 rows completed so far
# 4355000 rows completed so far
# 4360000 rows completed so far
# 4365000 rows completed so far
# 4370000 rows completed so far
# 4375000 rows completed so far
# 4380000 rows completed so far
# 4385000 rows completed so far
# 4390000 rows completed so far
# 4395000 rows completed so far
# 4400000 rows completed so far
# 4405000 rows completed so far
# 4410000 rows completed so far
# 4415000 rows completed so far
# 4420000 rows completed so far
# 4425000 rows completed so far
# 4430000 rows completed so far
# 4435000 rows completed so far
# 4440000 rows completed so far
# 4445000 rows completed so far
# 4450000 rows completed so far
# 4455000 rows completed so far
# 4460000 rows completed so far
# 4465000 rows completed so far
# 4470000 rows completed so far
# 4475000 rows completed so far
# 4480000 rows completed so far
# 4485000 rows completed so far
# 4490000 rows completed so far
# 4495000 rows completed so far
# 4500000 rows completed so far
# 4505000 rows completed so far
# 4510000 rows completed so far
# 4515000 rows completed so far
# 4520000 rows completed so far
# 4525000 rows completed so far
# 4530000 rows completed so far
# 4535000 rows completed so far
# 4540000 rows completed so far
# 4545000 rows completed so far
# 4550000 rows completed so far
# 4555000 rows completed so far
# 4560000 rows completed so far
# 4565000 rows completed so far
# 4570000 rows completed so far
# 4575000 rows completed so far
# 4580000 rows completed so far
# 4585000 rows completed so far
# 4590000 rows completed so far
# 4595000 rows completed so far
# 4600000 rows completed so far
# 4605000 rows completed so far
# 4610000 rows completed so far
# 4615000 rows completed so far
# 4620000 rows completed so far
# 4625000 rows completed so far
# 4630000 rows completed so far
# 4635000 rows completed so far
# 4640000 rows completed so far
# 4645000 rows completed so far
# 4650000 rows completed so far
# 4655000 rows completed so far
# 4660000 rows completed so far
