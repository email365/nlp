# %%
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    if not os.path.exists(filename):
        filename, _ = urlretrieve(url + filename, filename)
    statinfo = os.stat(filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified %s' % filename)
    else:
        print(statinfo.st_size)
        raise Exception(
            'Failed to verify ' + filename + '. Can you get to it with a browser?')
    return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words"""
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index=0 # dictionary['UNK']
            unk_count = unk_count + 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
    return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size // num_skips):
        target = skip_window  # target label at the center of the buffer
        targets_to_avoid = [ skip_window ]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'originated', 'a', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'anarchism', 'originated', 'a', 'originated', 'as', 'term', 'of']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):
    
    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # Variables
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
    
    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(
        tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                                   labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))
    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
    
    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
        normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001
with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(
            batch_size, num_skips, skip_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
        final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.969953
# Nearest to years: postulated, shigeru, teenager, proletarian, omnivorous, morals, astoria, beaulieu,
# Nearest to had: cfcs, lavin, ulrich, arctocephalus, stops, cameroon, reclaimed, rescheduled,
# Nearest to most: entscheidungsproblem, nightclubs, seize, wikibook, protects, novel, huddle, lizards,
# Nearest to if: dems, stat, needles, equilateral, maslow, revert, produce, radiotelephone,
# Nearest to however: zephaniah, dunbar, condor, pocketed, econometrics, feeding, exclude, salk,
# Nearest to war: bari, hugh, kyi, demonstrating, truman, drury, half, homosexuality,
# Nearest to can: thermonuclear, r, unanimous, hydrophilic, fick, andrews, diacritical, domesticated,
# Nearest to between: mafiosi, food, barred, thrice, emigrant, vp, capability, suzanne,
# Nearest to from: estonia, spontaneously, bitwise, variants, hopped, brassiere, administratively, mondegreens,
# Nearest to than: rufus, hdz, meninges, world, liberalized, maasai, italian, modulation,
# Nearest to are: imprints, lud, cyc, rw, tokelau, mie, hyperthyroidism, enki,
# Nearest to american: salah, homeschooling, intermixed, safer, dispersion, dramatised, trot, poll,
# Nearest to no: soviets, ordo, kluwer, nicola, rp, pulsar, schweitzer, reggie,
# Nearest to world: controversial, killian, hedonism, solferino, less, ganga, than, funds,
# Nearest to into: sloane, abbasid, deoxyribonucleic, glyphs, typified, cans, piled, unidentified,
# Nearest to people: atx, discernible, inflexible, ringo, dwt, house, rosy, nationals,
# Average loss at step 2000: 4.370258
# Average loss at step 4000: 3.862301
# Average loss at step 6000: 3.790183
# Average loss at step 8000: 3.691476
# Average loss at step 10000: 3.619616
# Nearest to years: teenager, bc, postulated, proletarian, embezzlement, astoria, halos, omnivorous,
# Nearest to had: has, have, was, lavin, cfcs, cannibalistic, clear, wrote,
# Nearest to most: entscheidungsproblem, more, congregationalists, testable, wikibook, behaviour, lizards, fatou,
# Nearest to if: dems, generally, tabernacle, inspected, calculations, moors, dignity, pogo,
# Nearest to however: problems, anders, walks, rub, until, mosander, pioneer, automata,
# Nearest to war: hugh, kyi, local, demonstrating, bari, bok, cyclist, implant,
# Nearest to can: would, andrews, may, must, accompanying, foxe, keefe, fick,
# Nearest to between: goebbels, masks, from, with, thrice, rejecting, thriller, in,
# Nearest to from: in, brassiere, into, hydroponic, on, tasty, hopped, between,
# Nearest to than: hdz, rufus, mittag, prefrontal, routers, xxx, small, sep,
# Nearest to are: were, is, have, was, enki, notate, convert, dai,
# Nearest to american: banaba, intermixed, computational, complements, mattered, katanga, homeschooling, salah,
# Nearest to no: soviets, schweitzer, ordo, improvements, clairvaux, lima, consisting, fujiko,
# Nearest to world: jody, silverman, widebody, solferino, funds, subregion, controversial, late,
# Nearest to into: daryl, from, in, by, with, buddy, deconstruction, deoxyribonucleic,
# Nearest to people: atx, ringo, epiphanes, diu, discernible, kan, mallow, nigel,
# Average loss at step 12000: 3.606712
# Average loss at step 14000: 3.580649
# Average loss at step 16000: 3.410133
# Average loss at step 18000: 3.463272
# Average loss at step 20000: 3.538699
# Nearest to years: months, bc, embezzlement, people, astoria, postulated, proletarian, scientology,
# Nearest to had: has, have, was, were, wrote, exemplified, clear, lavin,
# Nearest to most: more, entscheidungsproblem, wikibook, all, congregationalists, testable, some, playoff,
# Nearest to if: when, dems, ayub, pogo, where, jeux, tabernacle, mushrooms,
# Nearest to however: anders, walks, that, until, but, rub, problems, cask,
# Nearest to war: hugh, local, bok, luxuriant, drury, demonstrating, americanism, colons,
# Nearest to can: may, would, must, will, could, should, cannot, might,
# Nearest to between: from, in, masks, thriller, with, demolished, goebbels, rejecting,
# Nearest to from: into, in, between, tasty, editing, through, burials, by,
# Nearest to than: mittag, rufus, or, hdz, modulation, independence, much, sep,
# Nearest to are: were, is, have, was, romani, hunmin, enki, notate,
# Nearest to american: computational, banaba, aires, gina, russian, salah, poll, commences,
# Nearest to no: not, consisting, clairvaux, lima, recently, a, improvements, schweitzer,
# Nearest to world: jody, widebody, subregion, admixtures, silverman, solferino, late, funds,
# Nearest to into: from, daryl, with, by, on, deoxyribonucleic, nami, broadcasters,
# Nearest to people: years, epiphanes, atx, pesticides, nigel, men, countries, turkic,
# Average loss at step 22000: 3.501253
# Average loss at step 24000: 3.489424
# Average loss at step 26000: 3.480966
# Average loss at step 28000: 3.479017
# Average loss at step 30000: 3.503680
# Nearest to years: months, times, people, volumes, days, embezzlement, feet, bc,
# Nearest to had: have, has, was, were, wrote, before, magnificent, transactional,
# Nearest to most: more, some, entscheidungsproblem, many, playoff, wikibook, numerous, testable,
# Nearest to if: when, where, though, could, ayub, does, because, jeux,
# Nearest to however: but, anders, until, and, that, could, although, when,
# Nearest to war: americanism, cyborg, luxuriant, bok, drury, dreadnought, hugh, ignores,
# Nearest to can: may, would, will, could, must, should, might, cannot,
# Nearest to between: with, in, against, from, on, masks, under, inappropriate,
# Nearest to from: into, through, editing, after, between, hopped, in, of,
# Nearest to than: much, mittag, or, hdz, rufus, modulation, prefrontal, sep,
# Nearest to are: were, have, is, although, these, include, while, notate,
# Nearest to american: british, russian, english, elemental, indian, canadian, african, aires,
# Nearest to no: any, a, lima, not, shunning, chapters, schweitzer, mouthpiece,
# Nearest to world: jody, widebody, subregion, silverman, late, prosperity, edo, solferino,
# Nearest to into: from, through, around, daryl, disgruntled, deoxyribonucleic, on, with,
# Nearest to people: countries, men, years, others, cole, pesticides, those, atx,
# Average loss at step 32000: 3.497303
# Average loss at step 34000: 3.497665
# Average loss at step 36000: 3.456892
# Average loss at step 38000: 3.299683
# Average loss at step 40000: 3.428721
# Nearest to years: months, days, times, embezzlement, volumes, feet, issue, bc,
# Nearest to had: has, have, was, were, wrote, affluent, magnificent, declare,
# Nearest to most: more, many, some, playoff, both, numerous, fastest, wikibook,
# Nearest to if: when, where, is, jeux, ayub, though, diagonally, because,
# Nearest to however: but, that, anders, although, though, they, prophesied, until,
# Nearest to war: cyborg, luxuriant, bok, drury, hugh, dreadnought, ethica, hyperthyroidism,
# Nearest to can: may, could, will, would, must, should, might, cannot,
# Nearest to between: with, against, from, masks, on, brussel, azad, midwest,
# Nearest to from: through, into, in, between, towards, without, editing, after,
# Nearest to than: or, much, mittag, modulation, prefrontal, independence, clav, hdz,
# Nearest to are: were, have, is, although, include, be, notate, these,
# Nearest to american: indian, australian, cricketer, russian, british, aires, singers, canadian,
# Nearest to no: any, coarse, another, shunning, mouthpiece, chapters, serious, improvements,
# Nearest to world: jody, widebody, late, silverman, admixtures, advent, mossi, austerlitz,
# Nearest to into: from, through, around, daryl, disgruntled, down, metcalfe, deoxyribonucleic,
# Nearest to people: those, men, others, europeans, pesticides, cole, adequacy, atx,
# Average loss at step 42000: 3.431785
# Average loss at step 44000: 3.453040
# Average loss at step 46000: 3.448658
# Average loss at step 48000: 3.354357
# Average loss at step 50000: 3.383581
# Nearest to years: months, days, times, decades, feet, volumes, embezzlement, bc,
# Nearest to had: has, have, were, was, having, affluent, been, renn,
# Nearest to most: more, many, some, less, entscheidungsproblem, numerous, both, wikibook,
# Nearest to if: when, where, jeux, though, could, before, because, after,
# Nearest to however: but, although, though, that, while, until, when, anders,
# Nearest to war: cyborg, bok, luxuriant, arab, hyperthyroidism, malnutrition, brigitte, locks,
# Nearest to can: may, could, would, will, must, should, might, cannot,
# Nearest to between: with, against, involves, masks, in, under, displacing, over,
# Nearest to from: through, in, into, editing, sg, towards, galli, after,
# Nearest to than: or, much, mittag, but, modulation, and, clav, controversial,
# Nearest to are: were, is, have, although, those, dai, these, be,
# Nearest to american: indian, australian, cricketer, russian, aires, english, atlantic, mikvah,
# Nearest to no: any, coarse, shunning, chapters, mouthpiece, serious, recently, atwood,
# Nearest to world: jody, silverman, airflow, solferino, austerlitz, widebody, late, winfield,
# Nearest to into: through, from, around, daryl, on, by, soufriere, vampire,
# Nearest to people: men, others, cases, apathetic, those, decalogue, cole, countries,
# Average loss at step 52000: 3.440411
# Average loss at step 54000: 3.428546
# Average loss at step 56000: 3.439550
# Average loss at step 58000: 3.395177
# Average loss at step 60000: 3.393864
# Nearest to years: months, days, times, decades, hours, feet, volumes, embezzlement,
# Nearest to had: has, have, was, were, having, never, been, affluent,
# Nearest to most: many, more, some, both, less, entscheidungsproblem, especially, disseminated,
# Nearest to if: when, where, though, because, before, then, although, jeux,
# Nearest to however: but, although, though, that, while, until, which, when,
# Nearest to war: luxuriant, cyborg, bok, brigitte, dreadnought, locks, after, biographer,
# Nearest to can: may, would, could, will, must, might, should, cannot,
# Nearest to between: with, against, in, among, over, involves, masks, repulsion,
# Nearest to from: into, through, stripe, hopped, editing, tasty, tierra, saucers,
# Nearest to than: much, or, but, modulation, mittag, sure, and, mta,
# Nearest to are: were, is, have, include, although, these, those, be,
# Nearest to american: indian, australian, russian, african, english, mikvah, aires, atlantic,
# Nearest to no: any, shunning, coarse, chapters, mouthpiece, foundational, recently, little,
# Nearest to world: winfield, widebody, silverman, airflow, jody, edo, post, solferino,
# Nearest to into: through, from, around, daryl, in, standings, within, collared,
# Nearest to people: men, those, others, pesticides, cases, decalogue, europeans, countries,
# Average loss at step 62000: 3.244455
# Average loss at step 64000: 3.256102
# Average loss at step 66000: 3.408000
# Average loss at step 68000: 3.396697
# Average loss at step 70000: 3.359126
# Nearest to years: days, months, decades, times, hours, feet, volumes, centuries,
# Nearest to had: has, have, was, were, having, never, leaking, affluent,
# Nearest to most: more, many, some, less, hain, all, duets, linda,
# Nearest to if: when, though, where, before, because, jeux, although, since,
# Nearest to however: but, although, though, that, while, which, until, whispered,
# Nearest to war: cyborg, luxuriant, arab, locks, ethica, bok, mircea, celluloid,
# Nearest to can: may, could, would, will, must, should, might, cannot,
# Nearest to between: with, among, azad, from, within, against, in, repulsion,
# Nearest to from: through, into, in, between, stripe, by, brassiere, tierra,
# Nearest to than: or, much, but, mittag, and, modulation, sure, ansgar,
# Nearest to are: were, is, although, have, include, those, including, while,
# Nearest to american: indian, australian, english, tanzania, atlantic, british, mikvah, african,
# Nearest to no: any, shunning, serious, coarse, little, suspected, there, chapters,
# Nearest to world: silverman, widebody, post, winfield, edo, airflow, jody, advent,
# Nearest to into: through, from, around, within, standings, daryl, in, down,
# Nearest to people: men, those, others, cases, europeans, pesticides, countries, cole,
# Average loss at step 72000: 3.372358
# Average loss at step 74000: 3.349720
# Average loss at step 76000: 3.318213
# Average loss at step 78000: 3.346943
# Average loss at step 80000: 3.384870
# Nearest to years: months, days, times, decades, centuries, hours, year, minutes,
# Nearest to had: have, has, was, were, having, never, magnificent, saw,
# Nearest to most: many, more, some, less, especially, both, fastest, linda,
# Nearest to if: when, though, where, because, before, since, although, jeux,
# Nearest to however: although, but, though, that, while, whispered, until, where,
# Nearest to war: arab, cyborg, luxuriant, suck, wars, hyperthyroidism, sexuality, bok,
# Nearest to can: could, may, will, would, must, might, cannot, should,
# Nearest to between: with, among, within, over, against, in, from, inappropriate,
# Nearest to from: through, into, in, deconstruction, between, towards, galli, hopped,
# Nearest to than: or, much, but, and, mittag, une, even, modulation,
# Nearest to are: were, is, have, although, include, those, these, including,
# Nearest to american: australian, indian, british, atlantic, russian, singers, polish, tanzania,
# Nearest to no: little, coarse, any, serious, shunning, kwashiorkor, kirlian, db,
# Nearest to world: winfield, airflow, solferino, widebody, healing, silverman, post, edo,
# Nearest to into: through, from, within, around, standings, transcend, down, across,
# Nearest to people: men, those, cases, others, countries, women, europeans, pesticides,
# Average loss at step 82000: 3.407596
# Average loss at step 84000: 3.411455
# Average loss at step 86000: 3.389458
# Average loss at step 88000: 3.353152
# Average loss at step 90000: 3.366402
# Nearest to years: days, months, decades, times, hours, centuries, year, minutes,
# Nearest to had: has, have, were, was, having, failed, continued, magnificent,
# Nearest to most: many, more, some, less, especially, all, among, fastest,
# Nearest to if: when, where, though, before, since, jeux, after, although,
# Nearest to however: but, although, that, though, whispered, while, until, which,
# Nearest to war: arab, cyborg, suck, wars, during, locks, sexuality, descendant,
# Nearest to can: could, may, will, would, must, might, should, cannot,
# Nearest to between: with, within, against, among, in, over, from, azad,
# Nearest to from: through, into, towards, hopped, before, after, under, during,
# Nearest to than: or, much, mittag, even, collaborator, une, ansgar, subliminal,
# Nearest to are: were, is, have, include, these, those, although, be,
# Nearest to american: british, australian, indian, italian, african, russian, french, atlantic,
# Nearest to no: any, little, only, coarse, serious, shunning, realistic, become,
# Nearest to world: winfield, airflow, edo, widebody, acknowledge, ecstatic, post, silverman,
# Nearest to into: from, through, within, around, palpatine, standings, off, daryl,
# Nearest to people: men, those, women, brochure, europeans, god, children, multitasking,
# Average loss at step 92000: 3.396171
# Average loss at step 94000: 3.259271
# Average loss at step 96000: 3.362234
# Average loss at step 98000: 3.242848
# Average loss at step 100000: 3.361777
# Nearest to years: days, months, decades, year, times, hours, centuries, minutes,
# Nearest to had: has, have, was, having, were, would, anchors, saw,
# Nearest to most: more, less, especially, many, among, particularly, some, fastest,
# Nearest to if: when, where, though, before, since, jeux, kx, because,
# Nearest to however: but, although, though, that, especially, whispered, while, which,
# Nearest to war: wars, cyborg, suck, arab, luxuriant, sexuality, brigitte, celluloid,
# Nearest to can: could, may, will, would, must, should, cannot, might,
# Nearest to between: with, against, within, over, among, repulsion, involves, azad,
# Nearest to from: through, into, in, mcconnell, hopped, during, continuum, via,
# Nearest to than: or, much, mittag, ansgar, prefers, even, collaborator, douglass,
# Nearest to are: were, is, have, be, include, although, those, while,
# Nearest to american: british, australian, italian, indian, russian, canadian, english, french,
# Nearest to no: little, any, foundational, coarse, serious, shunning, earrings, only,
# Nearest to world: winfield, u, edo, silverman, airflow, circulated, healing, nchez,
# Nearest to into: through, within, from, off, around, palpatine, down, back,
# Nearest to people: men, women, jews, children, those, god, multitasking, screams,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
